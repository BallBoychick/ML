# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn import metrics
from sklearn import svm, datasets
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv('../data/balanced_sclaer_dataset_diabetes.csv')

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#           HighBP  HighChol  CholCheck       BMI    Smoker  Stroke  \
# 0       1.000000  0.000000   1.000000  0.279070  0.000000     0.0
# 1       0.000000  1.000000   1.000000  0.162791  0.000000     0.0
# 2       0.000000  1.000000   1.000000  0.174419  0.000000     0.0
# 3       1.000000  0.000000   1.000000  0.279070  1.000000     0.0
# 4       0.000000  1.000000   1.000000  0.337209  0.000000     0.0
# ...          ...       ...        ...       ...       ...     ...
# 105286  0.458320  0.458320   1.000000  0.388081  0.458320     0.0
# 105287  1.000000  1.000000   1.000000  0.234238  1.000000     0.0
# 105288  0.614436  1.000000   0.614436  0.186047  0.385564     0.0
# 105289  1.000000  1.000000   0.149867  0.106394  0.000000     0.0
# 105290  0.000000  0.112782   1.000000  0.280381  0.887218     0.0
#
#         HeartDiseaseorAttack  PhysActivity    Fruits  Veggies  ...  \
# 0                        0.0      1.000000  0.000000      1.0  ...
# ...

# %%
y = df["Diabetes_012"]
X = df.drop(["Diabetes_012"], axis=1)

# %%
train_X, test_X, train_Y, test_y = train_test_split(X, y, test_size=1/3)

# %%
gnb = GaussianNB()
gnb.fit(train_X[0:500], train_Y[0:500])
pred_train = gnb.predict(test_X[0:500])

# %%
train, test = train_test_split(df, test_size=.2, random_state=41)

# %%
from MyBayesClassifier import calculate_prior, calculate_likelihood_gaussian
from MyBayesClassifier import My_Naive_Bayes

# %%
X_test = test.iloc[:,:-1].values
Y_test = test.iloc[:,-1].values
XX_test = X_test[0:500]
YY_test = Y_test[0:500]
Y_pred = My_Naive_Bayes.naive_bayes_gaussian(df, X=XX_test, Y = "Diabetes_012")

# %%
X_test.shape
# Out:
# (21059, 21)

# %%
Y_pred
# Out:
# [2,
#  2,
#  2,
#  0,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  0,
#  2,
#  1,
#  0,
#  1,
#  0,
#  1,
#  2,
#  0,
#  2,
#  1,
#  0,
#  0,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  0,
#  0,
#  2,
#  0,
#  0,
#  2,
#  2,
#  2,
#  0,
#  1,
#  2,
#  1,
#  2,
#  0,
#  1,
#  1,
#  2,
#  1,
#  0,
#  2,
#  1,
#  1,
#  0,
#  0,
#  2,
#  0,
#  0,
#  1,
#  1,
#  0,
#  0,
#  0,
#  2,
#  0,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  0,
#  0,
#  1,
#  2,
#  0,
#  0,
#  1,
#  0,
#  2,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  2,
#  0,
#  1,
#  2,
#  1,
#  0,
#  2,
#  0,
#  2,
#  0,
#  0,
#  1,
#  0,
#  1,
#  0,
#  1,
#  2,
#  0,
#  1,
#  0,
#  0,
#  1,
#  0,
#  2,
#  0,
#  0,
#  1,
#  1,
#  2,
#  1,
#  1,
#  0,
#  1,
#  2,
#  0,
#  2,
#  1,
#  1,
#  2,
#  1,
#  0,
#  1,
#  1,
#  1,
#  1,
#  2,
#  0,
#  2,
#  0,
#  0,
#  2,
#  0,
#  1,
#  2,
#  1,
#  2,
#  0,
#  1,
#  2,
#  1,
#  2,
#  0,
#  1,
#  2,
#  1,
#  0,
#  1,
#  1,
#  1,
#  0,
#  0,
#  0,
#  1,
#  2,
# ...

# %%
accuracy_score(YY_test, Y_pred)
# Out:
# 0.548

# %%
print(classification_report(YY_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57       154
#          1.0       0.53      0.56      0.54       178
#          2.0       0.56      0.49      0.53       168
#
#     accuracy                           0.55       500
#    macro avg       0.55      0.55      0.55       500
# weighted avg       0.55      0.55      0.55       500

# %%
accuracy_score(test_y[0:500], pred_train)
# Out:
# 0.532

# %%
print(classification_report(test_y[0:500], pred_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.56      0.63       174
#          1.0       0.43      0.71      0.53       160
#          2.0       0.56      0.33      0.42       166
#
#     accuracy                           0.53       500
#    macro avg       0.57      0.53      0.53       500
# weighted avg       0.57      0.53      0.53       500
